# %%
import pandas as pd

# %%
df = pd.read_csv('Data/ship_fuel_efficiency.csv')
df.head()

# %%
df.columns
# Out:
# Index(['ship_id', 'ship_type', 'route_id', 'month', 'distance', 'fuel_type',
#        'fuel_consumption', 'CO2_emissions', 'weather_conditions',
#        'engine_efficiency', 'fuel_efficiency', 'fuel_usage'],
#       dtype='object')

# %%
import importlib
import fncts as fn

# %%
importlib.reload(fn)

# %% [markdown]
# top_n is from fncts.py

# %%
top_dist = fn.top_n(df,'distance',5)
top_dist
# Out:
#     ship_id    ship_type             route_id     month  distance fuel_type  \
# 793   NG067  Tanker Ship          Lagos-Apapa  February    498.55    Diesel
# 975   NG082  Tanker Ship          Lagos-Apapa     April    498.18       HFO
# 95    NG008  Tanker Ship          Lagos-Apapa  December    497.16    Diesel
# 438   NG037  Tanker Ship  Port Harcourt-Lagos      July    495.50       HFO
# 49    NG005  Tanker Ship       Escravos-Lagos  February    494.24       HFO
#
#      fuel_consumption  CO2_emissions weather_conditions  engine_efficiency  \
# 793          22973.21       62936.17             Stormy              70.49
# 975          17122.71       49536.57           Moderate              80.44
# 95           24648.52       62802.03               Calm              72.14
# 438          23070.00       59047.14               Calm              92.07
# 49           18375.75       46753.73             Stormy              94.18
#
#      fuel_efficiency  fuel_usage
# ...

# %%
top_fuel = fn.top_n(df,'fuel_consumption',5)
top_fuel
# Out:
#     ship_id    ship_type             route_id     month  distance fuel_type  \
# 95    NG008  Tanker Ship          Lagos-Apapa  December    497.16    Diesel
# 134   NG012  Tanker Ship          Warri-Bonny     March    490.16    Diesel
# 570   NG048  Tanker Ship          Lagos-Apapa      July    487.89       HFO
# 438   NG037  Tanker Ship  Port Harcourt-Lagos      July    495.50       HFO
# 793   NG067  Tanker Ship          Lagos-Apapa  February    498.55    Diesel
#
#      fuel_consumption  CO2_emissions weather_conditions  engine_efficiency  \
# 95           24648.52       62802.03               Calm              72.14
# 134          24321.40       71871.21               Calm              93.41
# 570          23503.71       65937.46               Calm              76.15
# 438          23070.00       59047.14               Calm              92.07
# 793          22973.21       62936.17             Stormy              70.49
#
#      fuel_efficiency  fuel_usage
# ...
